# %% [markdown]
# ## libraries

# %% [markdown]
# ### installation

# %% [markdown]
# pip install library_name

# %% [markdown]
# ### common libraries

# %%
import math

# Calculate square root
print(math.sqrt(16))  # Output: 4.0

# Calculate factorial
print(math.factorial(5))  # Output: 120
# Out:
# 4.0
# 120

# %%
import random

# Generate a random number between 1 and 10
print(random.randint(1, 10))  # Output: Random number between 1 and 10

# Choose a random element from a list
items = ['apple', 'banana', 'cherry']
print(random.choice(items))  # Output: Random item from the list
# Out:
# 5
# cherry

# %%
from datetime import datetime

# Get current date and time
now = datetime.now()
print("Current date and time:", now)

# Format the date
formatted_date = now.strftime("%Y-%m-%d %H:%M:%S")
print("Formatted date:", formatted_date)
# Out:
# Current date and time: 2024-09-06 22:51:45.451219
# Formatted date: 2024-09-06 22:51:45

# %%
import numpy as np

#numerical operations and arrays

# Create an array
arr = np.array([1, 2, 3, 4])
print("Array:", arr)

# Perform mathematical operations
print("Sum:", np.sum(arr))  # Output: 10
# Out:
# Array: [1 2 3 4]
# Sum: 10

# %%
import pandas as pd

#dataframes

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
print(df)

# Perform basic operations
print("Mean age:", df['Age'].mean())  # Output: Mean age: 30.0
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# Mean age: 30.0

# %% [markdown]
# ## numpy

# %% [markdown]
# numerical and scientific computing
# arrays and matrices

# %%
import numpy as np
# Creating an array
arr = np.array([1, 2, 3, 4])

# %%
# Trigonometric functions
theta = np.pi / 4
print(np.sin(theta))  # sin(π/4)

print(np.sin(1))

# Ceiling function
x = 2.3
print(np.ceil(x))  # rounds 2.3 up to 3
# Out:
# 0.7071067811865476
# 0.8414709848078965
# 3.0

# %%
# Generating values between 0 and 10
x_values = np.linspace(0, 10, 100)  # 100 evenly spaced values between 0 and 10
print(x_values)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %% [markdown]
# ## matplotlib

# %% [markdown]
# static, animated, and interactive plots
#
# visualization

# %%
import matplotlib.pyplot as plt

# Simple plot
x = np.linspace(0, 10, 100)
y = np.sin(x)
print(x)
print(y)
plt.plot(x, y)  # Plot y = sin(x)
plt.show()  # Display the plot
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
plt.plot(x, y, label="sin(x)", color='blue')
plt.title("Plot of sin(x)")
plt.xlabel("x axis")
plt.ylabel("sin(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, label="sin(x)")
plt.plot(x, y2, label="cos(x)")
plt.legend()
plt.show()
